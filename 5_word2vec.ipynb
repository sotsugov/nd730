# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'term', 'as', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.883819
# Nearest to may: herbicide, proposition, elca, glu, shanghainese, adequate, romulus, limbs,
# Nearest to by: zealanders, defines, ballpark, kernel, says, shelter, empowered, rates,
# Nearest to with: demolish, neutrality, benchmarking, stinging, cappadocia, derivations, urge, shorty,
# Nearest to while: rojcewicz, cse, inclusions, hope, imprinting, herding, tricycle, hesse,
# Nearest to during: bofh, fission, reproduce, dazzle, easternmost, caltrans, capitol, protagonist,
# Nearest to on: nielsen, commanders, alpine, syllable, pious, ferrous, trial, rajonas,
# Nearest to see: commedia, golem, sad, qam, delocalised, deuterium, seaplane, wilbur,
# Nearest to years: expressive, chopsticks, sectors, awa, bbses, brac, expressiveness, prescribing,
# Nearest to there: logicians, ingestion, godlike, displacements, opaque, althea, pig, outnumber,
# Nearest to system: jester, climbing, freefall, ltd, stacy, paulsen, confederacy, hanseatic,
# Nearest to after: rivalry, wise, sonia, tzu, methanol, mathrm, forcible, minas,
# Nearest to zero: wainwright, tonality, biplanes, tennant, blyton, abt, isotopes, lincoln,
# Nearest to an: layton, fucking, continuous, monza, midnight, kleine, tolkien, mussels,
# Nearest to are: chromatography, riders, cu, battlefront, whirlpool, furlongs, plight, gime,
# Nearest to more: beckton, sean, angus, province, grasped, conceded, polka, usurper,
# Nearest to that: applauded, irish, nucleons, climbs, follows, handicaps, philippa, parnassus,
# Average loss at step 2000: 4.370439
# Average loss at step 4000: 3.867444
# Average loss at step 6000: 3.790958
# Average loss at step 8000: 3.686395
# Average loss at step 10000: 3.609796
# Nearest to may: can, would, must, thursday, outlines, ordinal, sorrow, will,
# Nearest to by: was, be, with, greet, zealanders, uncompromising, during, lovely,
# Nearest to with: between, umbra, for, by, multistage, in, or, into,
# Nearest to while: ration, rojcewicz, inclusions, dispensation, hesse, guise, curl, greenstone,
# Nearest to during: at, dazzle, mahuad, easternmost, after, on, caltrans, bofh,
# Nearest to on: in, through, redox, commanders, of, during, boone, fused,
# Nearest to see: detonator, fellow, waring, kathryn, expositor, renowned, corso, bowmen,
# Nearest to years: chopsticks, acknowledgement, expressive, strikes, semiotics, populations, darshan, vats,
# Nearest to there: it, they, logicians, recipe, cfr, often, ratify, he,
# Nearest to system: jester, diary, freefall, climbing, heap, stele, didn, cruise,
# Nearest to after: during, methanol, wise, for, at, in, meteorology, tzu,
# Nearest to zero: five, nine, eight, six, three, seven, four, two,
# Nearest to an: ruddy, layton, appia, the, uncollected, episcopal, amer, dogs,
# Nearest to are: were, is, have, was, cics, massawa, systematic, ptolemaic,
# Nearest to more: analyzed, not, angus, no, ibizan, bennett, sports, magellan,
# Nearest to that: which, it, bradman, he, this, vries, holly, what,
# Average loss at step 12000: 3.602999
# Average loss at step 14000: 3.574114
# Average loss at step 16000: 3.407463
# Average loss at step 18000: 3.452318
# Average loss at step 20000: 3.543015
# Nearest to may: can, would, will, could, must, should, to, gina,
# Nearest to by: be, were, jonny, in, during, with, been, norton,
# Nearest to with: between, umbra, in, for, isoroku, by, or, inept,
# Nearest to while: dispensation, when, and, hesse, discs, outer, ration, coursing,
# Nearest to during: at, after, in, mahuad, totaled, by, dazzle, when,
# Nearest to on: in, at, through, under, during, ferrous, ena, metrics,
# Nearest to see: detonator, waring, gemological, embarked, katie, kathryn, expositor, maru,
# Nearest to years: acknowledgement, days, times, semiotics, chopsticks, populations, expressive, strikes,
# Nearest to there: they, it, which, he, we, often, recipe, who,
# Nearest to system: diary, heap, cruise, jester, freefall, internet, brahma, stele,
# Nearest to after: during, from, when, for, at, methanol, before, within,
# Nearest to zero: five, seven, six, four, nine, three, eight, two,
# Nearest to an: amer, appia, ticino, ruddy, forrester, uncollected, fucking, initiated,
# Nearest to are: were, is, have, stubby, include, megabyte, massawa, was,
# Nearest to more: less, analyzed, most, not, typesetting, angus, bennett, ibizan,
# Nearest to that: which, but, however, bradman, what, this, holly, kanem,
# Average loss at step 22000: 3.503494
# Average loss at step 24000: 3.489344
# Average loss at step 26000: 3.478576
# Average loss at step 28000: 3.483414
# Average loss at step 30000: 3.500003
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to by: been, was, were, with, during, jonny, in, as,
# Nearest to with: between, isoroku, against, lewisham, by, for, in, umbra,
# Nearest to while: when, although, dispensation, ration, discs, outer, resolvers, anemometers,
# Nearest to during: after, in, at, when, through, since, before, mahuad,
# Nearest to on: in, through, upon, into, under, at, during, medicaid,
# Nearest to see: embarked, gemological, waring, kathryn, holds, expositor, interlaced, detonator,
# Nearest to years: days, times, acknowledgement, months, semiotics, populations, minutes, year,
# Nearest to there: they, it, he, we, now, often, still, recipe,
# Nearest to system: systems, cruise, internet, diary, brahma, gallatin, description, proofs,
# Nearest to after: before, during, when, at, from, for, afterwards, methanol,
# Nearest to zero: five, four, seven, eight, six, three, nine, two,
# Nearest to an: amer, appia, uncollected, fucking, forrester, competitiveness, ticino, glyph,
# Nearest to are: were, is, have, include, be, massawa, compendium, these,
# Nearest to more: less, most, larger, longer, very, analyzed, readily, rather,
# Nearest to that: which, what, however, but, this, bradman, steamers, holly,
# Average loss at step 32000: 3.501357
# Average loss at step 34000: 3.490364
# Average loss at step 36000: 3.455635
# Average loss at step 38000: 3.300176
# Average loss at step 40000: 3.426143
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to by: when, with, profoundly, denise, norton, floated, zealanders, being,
# Nearest to with: between, when, by, in, multistage, inept, aerosols, discriminating,
# Nearest to while: although, when, dispensation, inlaid, was, though, resolvers, but,
# Nearest to during: after, at, when, since, through, against, before, on,
# Nearest to on: upon, through, during, in, at, from, assassinations, technician,
# Nearest to see: waring, embarked, gemological, laguna, expositor, roasting, bolan, include,
# Nearest to years: days, months, times, year, minutes, acknowledgement, decades, semiotics,
# Nearest to there: they, it, now, he, which, often, we, usually,
# Nearest to system: systems, cruise, diary, description, batavia, climbing, articulated, brahma,
# Nearest to after: before, when, during, from, at, despite, methanol, afterwards,
# Nearest to zero: seven, five, nine, eight, six, three, four, two,
# Nearest to an: glyph, amer, haggard, appia, forrester, ticino, casas, fucking,
# Nearest to are: were, is, have, be, include, megabyte, these, but,
# Nearest to more: less, most, larger, very, greater, longer, analyzed, readily,
# Nearest to that: which, however, what, this, bradman, but, ruthless, afterward,
# Average loss at step 42000: 3.434767
# Average loss at step 44000: 3.455757
# Average loss at step 46000: 3.447109
# Average loss at step 48000: 3.351888
# Average loss at step 50000: 3.382773
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to by: under, was, through, with, against, jonny, while, including,
# Nearest to with: between, by, epics, versa, when, aerosols, noa, nee,
# Nearest to while: when, although, however, for, but, and, though, where,
# Nearest to during: after, in, through, at, when, before, against, totaled,
# Nearest to on: upon, through, in, at, into, oslo, firmware, metrics,
# Nearest to see: include, embarked, roasting, waring, gemological, supp, laguna, holies,
# Nearest to years: days, months, times, decades, year, minutes, acknowledgement, semiotics,
# Nearest to there: they, it, he, now, she, we, often, illuminated,
# Nearest to system: systems, cruise, description, batavia, diary, articulated, interpreter, internet,
# Nearest to after: before, when, during, despite, while, if, afterwards, from,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to an: amer, fucking, appia, glyph, forrester, homily, kaufmann, uncollected,
# Nearest to are: were, is, have, be, those, include, was, innuendo,
# Nearest to more: less, most, larger, longer, very, greater, analyzed, readily,
# Nearest to that: which, however, what, this, but, bradman, krakatoa, mamoru,
# Average loss at step 52000: 3.437323
# Average loss at step 54000: 3.425747
# Average loss at step 56000: 3.437986
# Average loss at step 58000: 3.399332
# Average loss at step 60000: 3.393371
# Nearest to may: can, would, will, should, could, must, might, cannot,
# Nearest to by: through, with, cannae, countably, jonny, intensely, defines, including,
# Nearest to with: between, by, when, noa, tsim, in, isoroku, including,
# Nearest to while: although, when, though, however, before, were, including, after,
# Nearest to during: after, in, before, when, until, although, through, totaled,
# Nearest to on: upon, through, in, arbuthnot, redox, josef, papyri, at,
# Nearest to see: but, include, including, holies, embarked, can, gemological, compressor,
# Nearest to years: days, months, times, decades, minutes, year, centuries, people,
# Nearest to there: they, it, now, today, he, this, she, we,
# Nearest to system: systems, description, topics, cruise, diary, heap, weapons, internet,
# Nearest to after: before, during, when, despite, until, without, through, afterwards,
# Nearest to zero: five, seven, four, six, eight, nine, three, two,
# Nearest to an: appia, glyph, amer, haggard, forrester, fabricated, uncollected, fucking,
# Nearest to are: were, is, have, include, be, those, but, other,
# Nearest to more: less, larger, longer, most, very, rather, greater, further,
# Nearest to that: which, however, what, this, bradman, it, but, who,
# Average loss at step 62000: 3.237423
# Average loss at step 64000: 3.254824
# Average loss at step 66000: 3.402697
# Average loss at step 68000: 3.390233
# Average loss at step 70000: 3.357909
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to by: through, improve, using, lovely, jonny, being, heels, including,
# Nearest to with: between, isoroku, discriminating, aerosols, noa, incantations, hedeby, lewisham,
# Nearest to while: although, however, when, though, are, where, before, including,
# Nearest to during: after, before, in, until, through, boece, when, within,
# Nearest to on: upon, through, in, at, under, about, impediment, grigory,
# Nearest to see: include, but, can, references, laguna, topics, including, coogan,
# Nearest to years: days, months, decades, times, minutes, year, centuries, weeks,
# Nearest to there: they, it, now, we, usually, today, he, she,
# Nearest to system: systems, description, residing, heap, cruise, styles, embassies, topics,
# Nearest to after: before, during, when, despite, until, while, through, if,
# Nearest to zero: five, seven, four, six, eight, nine, three, two,
# Nearest to an: glyph, amer, forrester, evaluated, fucking, adret, flavia, scilly,
# Nearest to are: were, is, include, have, while, including, although, these,
# Nearest to more: less, most, larger, very, longer, further, increasingly, typesetting,
# Nearest to that: which, however, what, this, but, equivalence, where, fruitless,
# Average loss at step 72000: 3.373782
# Average loss at step 74000: 3.346960
# Average loss at step 76000: 3.319023
# Average loss at step 78000: 3.355396
# Average loss at step 80000: 3.378136
# Nearest to may: can, could, will, would, must, should, might, cannot,
# Nearest to by: through, using, when, including, against, norton, without, heels,
# Nearest to with: between, lemming, inept, including, isoroku, into, when, involving,
# Nearest to while: although, though, when, but, however, before, and, during,
# Nearest to during: after, in, when, before, until, through, despite, while,
# Nearest to on: upon, through, in, under, at, schema, prickly, inexpensively,
# Nearest to see: include, but, references, embarked, refer, barrett, identify, supp,
# Nearest to years: days, months, decades, times, minutes, weeks, year, centuries,
# Nearest to there: they, it, he, she, now, we, usually, often,
# Nearest to system: systems, cruise, embassies, description, topics, residing, cyclase, heap,
# Nearest to after: before, during, when, despite, until, while, from, following,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to an: glyph, amer, uncollected, adret, flavia, another, botany, fucking,
# Nearest to are: were, include, have, is, those, although, these, while,
# Nearest to more: less, most, longer, larger, very, increasingly, highly, further,
# Nearest to that: which, however, what, krakatoa, this, but, bradman, cavalli,
# Average loss at step 82000: 3.407483
# Average loss at step 84000: 3.409852
# Average loss at step 86000: 3.389589
# Average loss at step 88000: 3.353652
# Average loss at step 90000: 3.366505
# Nearest to may: can, could, should, would, must, might, will, cannot,
# Nearest to by: through, jonny, under, with, without, against, using, while,
# Nearest to with: between, in, lemming, by, into, inept, including, conjoined,
# Nearest to while: although, when, during, were, before, though, until, however,
# Nearest to during: after, before, in, while, despite, when, until, since,
# Nearest to on: upon, under, at, through, ferrous, punctuation, about, in,
# Nearest to see: include, list, references, supp, includes, barrett, roasting, bifurcation,
# Nearest to years: days, months, decades, minutes, times, weeks, year, hours,
# Nearest to there: it, they, he, we, now, she, usually, often,
# Nearest to system: systems, description, program, cruise, sacrament, residing, embassies, deceiving,
# Nearest to after: before, during, despite, until, when, if, without, while,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to an: another, glyph, uncollected, amer, botany, gahan, bail, solemnity,
# Nearest to are: were, is, include, these, have, those, contain, although,
# Nearest to more: less, most, longer, very, larger, increasingly, rather, highly,
# Nearest to that: which, however, what, but, bradman, krakatoa, ruthless, fruitless,
# Average loss at step 92000: 3.396247
# Average loss at step 94000: 3.255101
# Average loss at step 96000: 3.362042
# Average loss at step 98000: 3.243283
# Average loss at step 100000: 3.353970
# Nearest to may: can, could, should, must, might, would, will, cannot,
# Nearest to by: through, including, during, when, flugelhorn, using, without, snes,
# Nearest to with: between, including, isoroku, noa, into, lemming, ectopic, conjoined,
# Nearest to while: although, when, though, before, however, during, after, where,
# Nearest to during: after, in, before, despite, when, throughout, through, until,
# Nearest to on: upon, through, at, under, in, within, medicaid, gunmen,
# Nearest to see: list, refers, inuit, include, includes, references, ob, can,
# Nearest to years: days, months, decades, minutes, year, times, weeks, hours,
# Nearest to there: they, it, now, he, we, she, still, courtly,
# Nearest to system: systems, articulated, program, deceiving, heap, description, cruise, framework,
# Nearest to after: before, during, despite, when, until, without, through, following,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to an: another, glyph, uncollected, adret, gnaeus, evaluated, amer, metrodome,
# Nearest to are: were, have, include, is, although, those, these, be,
# Nearest to more: less, most, larger, very, longer, increasingly, further, highly,
# Nearest to that: which, however, what, bradman, krakatoa, who, this, but,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size // num_skips, 1), dtype=np.int32)
    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[target]

        labels[i , 0] = buffer[skip_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8 // num_skips)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'term', 'a', 'originated', 'term', 'originated', 'as', 'of']
#     labels: ['as', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default():
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size // num_skips, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    segments = tf.constant([x // num_skips for x in range(batch_size)])
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    embed = tf.segment_sum(embed, segments)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            weights=softmax_weights, biases=softmax_biases, inputs=embed,
            labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_cbow(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1: top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.983057
# Nearest to during: colombians, establish, obliged, erstwhile, guardian, insightful, caveat, knowles,
# Nearest to many: compute, podcast, assembly, vampyre, murals, osamu, waxes, metronome,
# Nearest to while: refurbished, gallifrey, magnetosphere, meaningful, sahib, windowing, isla, bleach,
# Nearest to first: lada, dtmf, adhered, observatory, trailed, atanasoff, mordecai, marmite,
# Nearest to eight: year, hipper, hosts, skeletons, ngo, parcham, jinx, subregion,
# Nearest to s: scriptural, jacky, suffixed, df, suit, optimisation, gambeson, proclamations,
# Nearest to with: lobbying, yisrael, bebe, wove, hao, fuzzy, opinion, paragraphs,
# Nearest to new: prediction, childless, kicking, undersecretary, businesses, jet, blackwood, ullman,
# Nearest to most: muscles, menagerie, hula, barker, withhold, impiety, clanking, adjacency,
# Nearest to such: rama, fari, important, disneyland, marshland, hetzel, wings, isolation,
# Nearest to but: aelia, philologist, persuaded, genotype, arawak, grover, patient, prey,
# Nearest to only: ids, font, fantastical, this, streamlining, escorting, cheetah, excommunicate,
# Nearest to into: surround, krylov, kingston, oxidative, probing, taland, sooty, tauris,
# Nearest to can: rahman, eleazar, piracy, aleppo, suborder, sagittarius, smartest, oneself,
# Nearest to will: clump, tanakh, insult, retailing, wiesbaden, dartmoor, tum, cassius,
# Nearest to would: asgard, comintern, survive, punishable, donning, prod, katakana, massoud,
# Average loss at step 2000: 4.222715
# Average loss at step 4000: 3.638645
# Average loss at step 6000: 3.538394
# Average loss at step 8000: 3.380526
# Average loss at step 10000: 3.297096
# Nearest to during: colleen, by, deserved, in, after, geothermal, legion, under,
# Nearest to many: some, several, these, other, genetics, eucharistic, tama, hbf,
# Nearest to while: magnetosphere, sen, shabda, headmaster, hoffmann, hdl, bulfinch, kierkegaard,
# Nearest to first: last, subdisciplines, kam, monocotyledons, tumble, sales, mordecai, pregnant,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to s: waltzes, fleeting, ja, its, alpacas, isbn, moo, mohs,
# Nearest to with: between, simulations, murron, elegant, dana, quakers, before, dot,
# Nearest to new: kicking, hopf, jet, ackerman, telecom, initiation, ltd, reinhard,
# Nearest to most: muscles, aedui, showcasing, airline, lorry, sunnis, more, reopen,
# Nearest to such: well, known, regarded, important, testes, iwo, matrimonial, disneyland,
# Nearest to but: and, prey, turf, wherein, pasternak, gesta, there, cycorp,
# Nearest to only: mica, strictly, furnaces, not, killings, font, shakespearean, priscus,
# Nearest to into: from, taland, stunned, lads, wicket, waxy, harmattan, surround,
# Nearest to can: would, may, will, could, must, should, cannot, might,
# Nearest to will: can, would, must, may, should, could, bothwell, does,
# Nearest to would: can, could, may, will, should, must, might, alboin,
# Average loss at step 12000: 3.267314
# Average loss at step 14000: 3.240807
# Average loss at step 16000: 3.023049
# Average loss at step 18000: 3.056747
# Average loss at step 20000: 3.159776
# Nearest to during: in, after, under, upon, at, until, when, paucity,
# Nearest to many: several, some, other, these, all, various, those, thorns,
# Nearest to while: although, when, magnetosphere, kierkegaard, are, sdk, from, conics,
# Nearest to first: last, second, next, third, troubles, reductionist, proletariat, codification,
# Nearest to eight: nine, seven, six, four, five, zero, three, two,
# Nearest to s: waltzes, antagonists, zulu, mark, roth, guideline, technicians, reservations,
# Nearest to with: between, by, censured, after, marlin, for, forbade, squaw,
# Nearest to new: kicking, jet, ltd, laminal, initiation, dina, telecom, clintons,
# Nearest to most: more, lorry, some, showcasing, aedui, highland, unreal, many,
# Nearest to such: known, well, regarded, these, testes, demille, playwright, jumo,
# Nearest to but: however, though, furnaces, he, bocce, that, if, since,
# Nearest to only: strictly, expenses, trot, trunks, jh, stingray, mica, whirl,
# Nearest to into: from, taland, through, on, lads, pandemonium, by, linking,
# Nearest to can: may, will, would, could, must, should, cannot, might,
# Nearest to will: would, can, must, may, could, should, might, cannot,
# Nearest to would: could, will, may, can, must, should, might, cannot,
# Average loss at step 22000: 3.117932
# Average loss at step 24000: 3.070880
# Average loss at step 26000: 3.054927
# Average loss at step 28000: 3.067348
# Average loss at step 30000: 3.086020
# Nearest to during: in, when, through, after, until, at, before, under,
# Nearest to many: several, some, those, lebeau, unprepared, humorists, stressing, hartford,
# Nearest to while: although, but, though, with, are, where, when, presheaf,
# Nearest to first: second, last, original, best, third, distantly, top, next,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to s: isbn, whose, montagu, loyalties, melos, his, glance, waltzes,
# Nearest to with: between, including, while, squaw, nara, cheltenham, lazarus, against,
# Nearest to new: jet, telecom, brush, kicking, blackwood, clintons, subclass, mainstream,
# Nearest to most: more, among, use, burr, lorry, some, particularly, gospel,
# Nearest to such: well, known, these, testes, regarded, consensus, described, overtaking,
# Nearest to but: however, though, although, while, and, provided, seductive, byers,
# Nearest to only: swanson, trot, furnaces, play, amounting, strictly, nine, fracture,
# Nearest to into: from, through, under, sudden, in, taland, on, around,
# Nearest to can: may, could, should, would, will, must, cannot, might,
# Nearest to will: may, would, must, can, should, could, might, cannot,
# Nearest to would: could, will, may, can, should, might, must, cannot,
# Average loss at step 32000: 3.075131
# Average loss at step 34000: 3.050574
# Average loss at step 36000: 2.993377
# Average loss at step 38000: 2.795963
# Average loss at step 40000: 2.972603
# Nearest to during: in, after, graphene, at, within, foucault, before, lysis,
# Nearest to many: several, some, various, those, these, numerous, other, alkmaar,
# Nearest to while: although, after, like, where, but, when, phishing, pontic,
# Nearest to first: second, last, next, original, best, fourth, third, distantly,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to s: isbn, asterism, wool, citt, his, whose, loyalties, waltzes,
# Nearest to with: against, between, by, dana, winn, transubstantiation, in, marceau,
# Nearest to new: jet, modern, telecom, premierships, kicking, soaring, brief, mainstream,
# Nearest to most: more, particularly, lorry, very, less, showcasing, crest, thatcher,
# Nearest to such: well, defined, known, regarded, these, iwo, including, follows,
# Nearest to but: however, although, while, though, and, generally, digamma, are,
# Nearest to only: strictly, thetis, comte, priscus, dictionnaire, strive, not, bernini,
# Nearest to into: through, from, dharmas, soc, chatting, in, stunned, broadband,
# Nearest to can: could, will, may, must, would, should, cannot, might,
# Nearest to will: can, would, could, must, should, may, might, cannot,
# Nearest to would: will, could, can, might, should, must, may, cannot,
# Average loss at step 42000: 2.976320
# Average loss at step 44000: 2.995424
# Average loss at step 46000: 2.975655
# Average loss at step 48000: 2.889302
# Average loss at step 50000: 2.894773
# Nearest to during: in, after, when, throughout, from, at, under, until,
# Nearest to many: several, some, various, numerous, both, those, most, these,
# Nearest to while: when, although, however, though, where, after, including, but,
# Nearest to first: last, second, next, entire, original, third, southern, netherlands,
# Nearest to eight: nine, six, seven, four, zero, five, three, two,
# Nearest to s: isbn, whose, asterism, antonym, citt, taxable, ja, adamic,
# Nearest to with: between, squaw, deeps, against, by, supersonic, when, births,
# Nearest to new: brief, mainstream, spectral, telecom, clintons, penitent, subclass, argus,
# Nearest to most: more, many, less, crest, lorry, caution, romney, very,
# Nearest to such: well, known, regarded, these, follows, iwo, defined, thermodynamic,
# Nearest to but: however, though, although, while, or, atalh, where, antigen,
# Nearest to only: always, dictionnaire, ceos, screwed, universe, strictly, do, best,
# Nearest to into: through, from, stunned, dharmas, towards, over, within, unmistakable,
# Nearest to can: could, must, would, should, may, might, will, cannot,
# Nearest to will: would, could, should, can, must, may, might, cannot,
# Nearest to would: could, will, can, might, must, may, should, cannot,
# Average loss at step 52000: 2.951621
# Average loss at step 54000: 2.943886
# Average loss at step 56000: 2.951512
# Average loss at step 58000: 2.873790
# Average loss at step 60000: 2.893836
# Nearest to during: after, before, in, within, when, although, under, until,
# Nearest to many: some, several, numerous, various, these, such, all, multiple,
# Nearest to while: although, before, though, when, during, cursor, gondwana, but,
# Nearest to first: last, second, next, third, latter, same, magnifying, fourth,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to s: isbn, winona, whose, irma, waltzes, adult, roskilde, materialize,
# Nearest to with: between, when, births, including, perdition, by, elegant, in,
# Nearest to new: current, labrador, subclass, brief, clintons, definitive, specific, mainstream,
# Nearest to most: less, more, oldest, many, caution, some, all, martyn,
# Nearest to such: well, these, regarded, known, thermodynamic, iwo, many, few,
# Nearest to but: however, although, though, see, and, triangles, falconiformes, while,
# Nearest to only: always, usually, until, all, robot, actually, typically, universe,
# Nearest to into: through, under, from, guerre, in, within, linking, towards,
# Nearest to can: could, may, would, should, might, must, cannot, will,
# Nearest to will: could, would, should, must, may, can, might, cannot,
# Nearest to would: could, will, must, should, can, might, may, cannot,
# Average loss at step 62000: 2.685381
# Average loss at step 64000: 2.702025
# Average loss at step 66000: 2.870890
# Average loss at step 68000: 2.898347
# Average loss at step 70000: 2.834302
# Nearest to during: in, until, before, within, throughout, after, despite, since,
# Nearest to many: some, several, numerous, various, all, most, unprepared, multiple,
# Nearest to while: although, however, when, before, cursor, like, though, specialty,
# Nearest to first: second, last, next, third, original, best, fourth, same,
# Nearest to eight: nine, six, seven, four, five, zero, three, one,
# Nearest to s: isbn, whose, dumont, constabulary, asterism, waltzes, insubordination, minsk,
# Nearest to with: between, perdition, by, if, elegant, client, without, among,
# Nearest to new: different, computerized, brush, clintons, modern, subclass, initiation, jet,
# Nearest to most: more, less, particularly, many, lorry, very, showcasing, gospel,
# Nearest to such: these, regarded, well, known, thermodynamic, iwo, follows, openstep,
# Nearest to but: however, though, and, than, bocce, while, although, should,
# Nearest to only: always, errant, relationship, last, ascribed, still, furnaces, cnt,
# Nearest to into: from, through, within, under, in, disambiguation, aggadah, off,
# Nearest to can: may, could, should, would, must, might, will, cannot,
# Nearest to will: would, should, may, must, could, can, might, cannot,
# Nearest to would: could, will, should, may, can, might, must, cannot,
# Average loss at step 72000: 2.854850
# Average loss at step 74000: 2.827803
# Average loss at step 76000: 2.809834
# Average loss at step 78000: 2.819314
# Average loss at step 80000: 2.846985
# Nearest to during: in, after, despite, when, before, although, throughout, on,
# Nearest to many: several, some, numerous, various, most, all, both, few,
# Nearest to while: although, though, including, when, but, however, and, after,
# Nearest to first: last, second, next, third, fifth, fourth, best, same,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to s: isbn, unsatisfied, cola, insubordination, whose, asterism, and, unwin,
# Nearest to with: against, nara, faroe, clearwater, perdition, when, winn, jsf,
# Nearest to new: narrative, computerized, nullify, mainstream, old, modern, single, classic,
# Nearest to most: more, many, some, less, quite, caution, particularly, beauregard,
# Nearest to such: well, regarded, follows, these, seen, thermodynamic, defined, karamanlis,
# Nearest to but: however, occurs, although, while, though, see, and, will,
# Nearest to only: errant, frame, always, last, ascribed, fanfiction, limited, cassette,
# Nearest to into: through, from, within, towards, beyond, dharmas, off, chatting,
# Nearest to can: could, would, may, will, should, must, cannot, might,
# Nearest to will: would, could, may, should, can, might, cannot, must,
# Nearest to would: could, will, should, might, must, can, may, cannot,
# Average loss at step 82000: 2.881950
# Average loss at step 84000: 2.893269
# Average loss at step 86000: 2.856993
# Average loss at step 88000: 2.815618
# Average loss at step 90000: 2.818674
# Nearest to during: after, before, in, until, through, despite, from, under,
# Nearest to many: some, several, numerous, these, all, various, few, anaesthetics,
# Nearest to while: before, though, were, during, when, after, and, although,
# Nearest to first: second, last, third, next, fifth, fourth, latter, earliest,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to s: isbn, our, your, whose, incur, constabulary, his, hated,
# Nearest to with: between, without, by, in, using, murron, dana, deeps,
# Nearest to new: hopf, specific, montague, narrative, figured, modern, definitive, nutcracker,
# Nearest to most: all, some, many, more, lorry, among, oldest, past,
# Nearest to such: well, known, follows, regarded, accra, thermodynamic, described, testes,
# Nearest to but: however, and, probably, though, although, he, yet, immediately,
# Nearest to only: no, last, errant, comte, ascribed, every, reloaded, even,
# Nearest to into: through, from, within, aggadah, onto, around, guerre, kirlian,
# Nearest to can: could, cannot, may, will, should, must, might, would,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to would: will, could, should, might, may, must, can, cannot,
# Average loss at step 92000: 2.861271
# Average loss at step 94000: 2.692531
# Average loss at step 96000: 2.815623
# Average loss at step 98000: 2.696620
# Average loss at step 100000: 2.819492
# Nearest to during: in, despite, after, throughout, until, when, under, following,
# Nearest to many: several, some, numerous, these, various, few, all, those,
# Nearest to while: when, although, before, though, furthermore, and, after, whereas,
# Nearest to first: last, next, third, second, fourth, fifth, final, latter,
# Nearest to eight: seven, nine, four, six, five, three, zero, two,
# Nearest to s: whose, isbn, asterism, siemens, your, although, my, fabien,
# Nearest to with: between, besides, dana, inductive, interpolated, among, perdition, to,
# Nearest to new: specific, mainstream, different, modern, minor, clintons, nutcracker, traditional,
# Nearest to most: more, less, especially, increasingly, particularly, lorry, very, cop,
# Nearest to such: well, known, follows, defined, opposed, regarded, including, many,
# Nearest to but: however, and, although, probably, named, welcoming, though, aleksei,
# Nearest to only: no, last, comte, kammu, reloaded, beltane, approximant, yusuf,
# Nearest to into: through, within, beyond, onto, under, across, guerre, from,
# Nearest to can: could, may, will, should, must, cannot, would, might,
# Nearest to will: would, could, should, must, can, may, cannot, might,
# Nearest to would: will, could, might, should, can, may, cannot, must,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), 
                       textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ## Skip-gram:
# * Works well with small amount of the training data
# * Represents well even rare words or phrases
# ## CBOW:
# * Several times faster to train than skip-gram
# * Slightly better accuracy for the frequent words
