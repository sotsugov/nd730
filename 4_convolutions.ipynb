# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.262049
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.438284
# Minibatch accuracy: 50.0%
# Validation accuracy: 57.0%
# Minibatch loss at step 100: 1.642677
# Minibatch accuracy: 37.5%
# Validation accuracy: 67.1%
# Minibatch loss at step 150: 0.302949
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.4%
# Minibatch loss at step 200: 0.848670
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 250: 1.011784
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 300: 1.033855
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 350: 0.372897
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 400: 0.383125
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 1.104001
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 500: 0.358837
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 550: 0.960717
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 600: 0.514833
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.450381
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 700: 1.402009
# Minibatch accuracy: 56.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 750: 0.439756
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 800: 0.760238
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 850: 0.849465
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 900: 0.964780
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.615839
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1000: 0.621846
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Test accuracy: 89.9%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
# hyperparameters
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
num_steps = 1001


graph = tf.Graph()
with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32,shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(
        tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(pool + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(pool + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))


with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 100 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.360740
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.9%
# Minibatch loss at step 100: 1.384010
# Minibatch accuracy: 50.0%
# Validation accuracy: 58.7%
# Minibatch loss at step 200: 0.875477
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 300: 1.047618
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 400: 0.284612
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 500: 0.459775
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 600: 0.653982
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 700: 1.252847
# Minibatch accuracy: 50.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 800: 0.790649
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 900: 0.846379
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 1000: 0.691931
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
num_channels = 1

c1_depth = 6
c1_ker_sz = 5
c3_depth = 16
c3_ker_sz = 6
c5_depth = 120
c5_ker_sz = 6

num_hidden = 84
num_steps = 20000

graph = tf.Graph()
with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(
        tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    c1_weights = tf.Variable(tf.truncated_normal(
        [c1_ker_sz, c1_ker_sz, num_channels, c1_depth], stddev=0.1))
    c1_biases = tf.Variable(tf.zeros([c1_depth]))
    c3_weights = tf.Variable(tf.truncated_normal(
        [c3_ker_sz, c3_ker_sz, c1_depth, c3_depth], stddev=0.1))
    c3_biases = tf.Variable(tf.constant(1.0, shape=[c3_depth]))
    c5_weights = tf.Variable(tf.truncated_normal(
        [c5_ker_sz, c5_ker_sz, c3_depth, c5_depth], stddev=0.1))
    c5_biases = tf.Variable(tf.constant(1.0, shape=[c5_depth]))
    c5_conv_dim = (((((image_size + 1)//2) + 1) // 2) + 1 )//2
    fc_weights = tf.Variable(tf.truncated_normal(
        [c5_conv_dim * c5_conv_dim * c5_depth, num_hidden], stddev=0.1))
    fc_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    out_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    out_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        print(data.get_shape().as_list())
        conv = tf.nn.conv2d(data, c1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + c1_biases)
        print(conv.get_shape().as_list())
        pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        print(pooled.get_shape().as_list())
        conv = tf.nn.conv2d(pooled, c3_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + c3_biases)
        pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = pooled.get_shape().as_list()
        print(shape)
        conv = tf.nn.conv2d(pooled, c5_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + c5_biases)
        pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = pooled.get_shape().as_list()
        print(shape)
        reshape = tf.reshape(pooled, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, fc_weights) + fc_biases)
        return tf.matmul(hidden, out_weights) + out_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    #optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    optimizer = tf.train.AdagradOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 100 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# [16, 28, 28, 1]
# [16, 28, 28, 6]
# [16, 14, 14, 6]
# [16, 7, 7, 16]
# [16, 4, 4, 120]
# [10000, 28, 28, 1]
# [10000, 28, 28, 6]
# [10000, 14, 14, 6]
# [10000, 7, 7, 16]
# [10000, 4, 4, 120]
# [10000, 28, 28, 1]
# [10000, 28, 28, 6]
# [10000, 14, 14, 6]
# [10000, 7, 7, 16]
# [10000, 4, 4, 120]
# Initialized
# Minibatch loss at step 0: 8.273956
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 1.621075
# Minibatch accuracy: 31.2%
# Validation accuracy: 60.6%
# Minibatch loss at step 200: 0.892626
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.1%
# Minibatch loss at step 300: 0.899097
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 400: 0.322053
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 500: 0.432410
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 600: 0.532211
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 700: 1.114814
# Minibatch accuracy: 56.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 800: 0.772279
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 900: 0.869003
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 1000: 0.627607
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 1100: 0.546746
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 1200: 0.342587
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 1300: 0.668122
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 1400: 0.613929
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 1500: 0.372175
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 1600: 0.410376
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 1700: 0.288360
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 1800: 0.803323
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 1900: 0.119051
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 2000: 0.523103
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 2100: 0.099378
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 2200: 0.477817
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 2300: 0.392039
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 2400: 0.215912
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 2500: 0.186447
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 2600: 0.239354
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 2700: 0.176962
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 2800: 0.176026
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 2900: 0.518210
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 3000: 0.496692
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 3100: 0.171448
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 3200: 0.511437
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 3300: 0.223599
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 3400: 0.304835
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 3500: 0.021180
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 3600: 0.321788
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 3700: 0.446237
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 3800: 0.573719
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 3900: 0.432423
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 4000: 0.262742
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 4100: 0.432290
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 4200: 0.435284
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 4300: 0.180769
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 4400: 1.095238
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 4500: 0.404672
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 4600: 0.328754
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 4700: 0.472904
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 4800: 0.342847
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 4900: 0.340843
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 5000: 0.601976
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 5100: 0.298370
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 5200: 0.350176
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 5300: 0.435628
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 5400: 0.496000
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 5500: 0.066311
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 5600: 0.073461
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 5700: 0.190786
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 5800: 1.021109
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 5900: 0.368860
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 6000: 0.454066
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 6100: 0.697319
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 6200: 0.253602
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 6300: 0.066209
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 6400: 0.364918
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 6500: 0.056900
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 6600: 0.823200
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 6700: 0.452321
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 6800: 0.596684
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 6900: 0.291910
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 7000: 0.581759
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 7100: 0.521848
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 7200: 0.240004
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 7300: 0.452333
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 7400: 0.437466
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 7500: 0.074539
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 7600: 0.605944
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 7700: 0.132087
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 7800: 0.068632
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 7900: 0.683771
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 8000: 0.426647
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 8100: 0.400060
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 8200: 0.482329
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 8300: 0.300666
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 8400: 0.278145
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 8500: 0.335164
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 8600: 0.198822
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 8700: 0.594759
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 8800: 0.043929
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 8900: 0.117468
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 9000: 0.447055
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 9100: 0.384156
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 9200: 0.109933
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 9300: 0.415786
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 9400: 0.106631
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 9500: 0.404262
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 9600: 0.223274
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 9700: 0.176610
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 9800: 0.821991
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 9900: 0.057711
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 10000: 0.054643
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 10100: 0.348339
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 10200: 0.767107
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 10300: 0.362876
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 10400: 0.365575
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 10500: 0.251311
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 10600: 0.099176
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 10700: 0.703193
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 10800: 0.483533
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 10900: 0.523523
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 11000: 0.657320
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 11100: 0.434043
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 11200: 0.031559
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 11300: 0.496992
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 11400: 0.252529
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 11500: 0.289081
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 11600: 0.397153
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 11700: 0.280755
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 11800: 0.247022
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 11900: 0.055837
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 12000: 0.093963
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 12100: 0.264140
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 12200: 0.236597
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 12300: 0.243317
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 12400: 0.152886
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 12500: 0.162272
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 12600: 0.046436
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# Minibatch loss at step 12700: 0.492471
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 12800: 0.189292
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 12900: 0.701521
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 13000: 0.058323
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 13100: 0.768206
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 13200: 0.287473
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 13300: 0.189504
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 13400: 0.457922
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 13500: 0.162083
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 13600: 0.236159
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 13700: 0.150222
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 13800: 0.235460
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 13900: 0.711842
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 14000: 0.427148
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 14100: 0.065597
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 14200: 0.302120
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 14300: 0.309068
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 14400: 0.271609
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 14500: 0.532653
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 14600: 0.336591
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 14700: 0.050385
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 14800: 0.456978
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 14900: 0.482635
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 15000: 0.518433
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 15100: 0.119463
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 15200: 0.348462
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 15300: 0.163577
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 15400: 0.440872
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 15500: 0.122418
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 15600: 0.195393
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 15700: 0.253537
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 15800: 0.152951
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 15900: 0.437972
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 16000: 0.418133
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 16100: 0.590834
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 16200: 0.623042
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 16300: 0.416891
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 16400: 0.168938
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 16500: 0.606518
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 16600: 0.381696
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 16700: 0.906236
# Minibatch accuracy: 75.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 16800: 0.408490
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 16900: 0.198579
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 17000: 0.075067
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 17100: 0.508255
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 17200: 0.383399
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 17300: 0.614701
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 17400: 0.144589
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 17500: 0.225802
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 17600: 0.027478
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# Minibatch loss at step 17700: 0.026810
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 17800: 0.113275
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 17900: 0.014094
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# Minibatch loss at step 18000: 0.064142
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 18100: 0.293106
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 18200: 0.006014
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 18300: 0.284852
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 18400: 0.285089
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 18500: 0.340909
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 18600: 0.559897
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 18700: 0.262487
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 18800: 0.244373
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 18900: 0.348439
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 19000: 0.301909
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 19100: 0.434730
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 19200: 0.013148
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 19300: 0.171597
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 19400: 0.403134
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 19500: 0.050535
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 19600: 0.040741
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 19700: 0.054263
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 19800: 0.426291
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 19900: 0.374002
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Test accuracy: 95.8%
